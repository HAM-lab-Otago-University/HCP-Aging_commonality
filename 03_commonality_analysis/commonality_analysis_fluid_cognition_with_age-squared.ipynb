# %% [markdown]
# ##### This notebook contains code to conduct commonality analysis

# %%
#load libraries
import pandas as pd
import numpy as np
import glob
import os

from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from scipy.stats import pearsonr
from scipy.stats import linregress

# %%
#function return r2 from linear regression between feature(s) and target
def get_r2(X, y):
    if len(X.shape)<2:
        r2 = LinearRegression().fit(StandardScaler().fit_transform(X.values.reshape(-1, 1)), y).score(StandardScaler().fit_transform(X.values.reshape(-1, 1)), y)
    else:
        r2 = LinearRegression().fit(StandardScaler().fit_transform(X.values), y).score(StandardScaler().fit_transform(X.values), y)
    return r2

# %%
#function return r2 from linear regression between feature(s) and target
def get_r2(X, y):
    if len(X.shape)<2:
        
        lin
        r2 = LinearRegression().fit(StandardScaler().fit_transform(X.values.reshape(-1, 1)), y).score(StandardScaler().fit_transform(X.values.reshape(-1, 1)), y)
    else:
        r2 = LinearRegression().fit(StandardScaler().fit_transform(X.values), y).score(StandardScaler().fit_transform(X.values), y)
    return r2

# %%
#path to output directory 
path = '/media/data/HCPAging/data/MLTablesMultCon/output_5cv_sexAdj_noStdTarg_STDstackFeatures/'

# %%
#load dataframes

#age prediction from test
df_age = pd.read_csv(path+'output_5cv_sexAdj_noStdTarg_STDstackFeatures_interview_age/all_fold_y-pred_y-obs.csv', index_col=0)
#age prediction from train
df_age_train = pd.read_csv(path+'output_5cv_sexAdj_noStdTarg_STDstackFeatures_interview_age/all_fold_y-pred_y-obs_train.csv', index_col=0)
#fluid cognition prediction
df_cog = pd.read_csv(path+'output_5cv_sexAdj_noStdTarg_STDstackFeatures_nih_fluidcogcomp_unadjusted/all_fold_y-pred_y-obs.csv', index_col=0)

# %%
#define original targets and predicted values for each type
cog_orig = df_cog['y_real']
cog_pred = df_cog.iloc[:, :-2]

age_orig = df_age['y_real']
age_pred = df_age.iloc[:, :-2]

# %%
#calculate brain age corrected

dct_corrected ={}

for fold in sorted(set(df_age_train['fold'])):
    dct_corrected[fold] ={}
    
    df_pred = df_age_train[df_age_train['fold']==fold].iloc[:, :-2]
    df_orig = df_age_train[df_age_train['fold']==fold]['y_real']
    df_test = df_age[df_age['fold']==fold].iloc[:, :-2]
    
    for col in df_pred.columns:
        slope, intercept, _, _, _, = linregress(df_orig, df_pred[col])
        
        out = (df_test[col] - intercept)/slope
        
        
        dct_corrected[fold][col]= out
        
age_pred_cor = pd.DataFrame(dct_corrected[0])
for fold in sorted(set(df_age_train['fold']))[1:]:
    age_pred_cor = pd.concat([age_pred_cor, pd.DataFrame(dct_corrected[fold])], axis=0)

# %%
#calculate brain age gap, usual and corrected

age_gap = pd.DataFrame()
for col in age_pred.columns:
    age_gap[col] = age_orig - age_pred[col]


age_gap_cor = pd.DataFrame()
for col in age_pred_cor.columns:
    age_gap_cor[col] = age_orig - age_pred_cor[col]

# %%
# one predictor
#cognition                              cog_orig        1
#age                                    age_orig        1
#brain age                              age_pred        26
#brain age gap (delta)                  age_gap         26
#corrected brain age                    age_pred_cor    26
#corrected brain age gap (delta)        age_gap_cor     26

# %%
age_orig_sqrd = age_orig **2

# %%
age_orig_sqrd
# Out:
# HCA6051047    525625
# HCA6075263    588289
# HCA6086470    236196
# HCA6095572    802816
# HCA6098073    935089
#                ...
# HCA9912492    680625
# HCA9913090    904401
# HCA9938814    316969
# HCA9953406    321489
# HCA9992517    419904
# Name: y_real, Length: 504, dtype: int64

# %%
#Predicting cognition with age

#one predictor (one of brain age indexes)

dct_r2_one = {}
dct_corR_one = {}
dct_corPval_one = {}

for dset, dset_name in zip([age_orig, age_pred, age_gap, age_pred_cor, age_gap_cor], 
                           ['age_orig', 'age_pred', 'age_gap', 'age_pred_cor', 'age_gap_cor']):  
    #
    
    if len(dset.shape)<2:
        
        dct_r2_one[dset_name] = get_r2(pd.concat([age_orig, age_orig_sqrd], axis=1), cog_orig) ###
        
    else:
        
        dct_r2_one[dset_name] = {}
        dct_corR_one[dset_name] = {}
        dct_corPval_one[dset_name] = {}
        
        for col in dset.columns:
            
            dct_r2_one[dset_name][col] = get_r2(dset[col], cog_orig)
            dct_corR_one[dset_name][col], dct_corPval_one[dset_name][col] = pearsonr(dset[col], cog_orig)
        
        dct_r2_one[dset_name] = pd.Series(dct_r2_one[dset_name])
        dct_corR_one[dset_name] = pd.Series(dct_corR_one[dset_name])
        dct_corPval_one[dset_name] = pd.Series(dct_corPval_one[dset_name])

print('Predicting cognition with age')
print(' ')
print('age_orig', dct_r2_one['age_orig'])
print('age_orig correlation with cog', pearsonr(age_orig, cog_orig))

df_r2_one = pd.DataFrame()
df_corR_one = pd.DataFrame()
df_corPval_one = pd.DataFrame()

for key in list(dct_r2_one.keys())[1:]:
    df_r2_one['r2_1_'+key] = dct_r2_one[key]
    df_corR_one['R_1_'+key] = dct_corR_one[key]
    df_corPval_one['Pval_1_'+key] = dct_corPval_one[key]

print(' ')    
print('R2')    
display(df_r2_one.round(6))
print(' ') 
print('Correlation')
display(df_corR_one.round(6))
print(' ') 
print('Pvalue for correlation')
display(df_corPval_one.round(6))
# Out:
# Predicting cognition with age
#
# age_orig 0.3255123424089824
# age_orig correlation with cog PearsonRResult(statistic=-0.5663319265729474, pvalue=4.353600662708515e-44)
#
# R2
#           r2_1_age_pred  r2_1_age_gap  r2_1_age_pred_cor  r2_1_age_gap_cor
# carit1         0.052275      0.278114           0.056524          0.036141
# carit3         0.101934      0.228756           0.105562          0.028827
# carit4         0.051659      0.267819           0.052987          0.022561
# face1          0.118230      0.199998           0.114327          0.012302
# face2          0.115699      0.199401           0.118205          0.014101
# face3          0.113068      0.223987           0.115074          0.006080
# face4          0.043832      0.272638           0.044384          0.026787
# face5          0.166395      0.165657           0.166601          0.007732
# face6          0.175158      0.166654           0.166113          0.002471
# vism           0.129792      0.195600           0.132140          0.012664
# carit_FC       0.177783      0.209544           0.181093          0.013119
# face_FC        0.187514      0.206923           0.187038          0.023722
# vism_FC        0.162493      0.208230           0.163470          0.015543
# cort           0.243717      0.078859           0.243367          0.000693
# surf           0.110972      0.221149           0.113687          0.013491
# subc           0.236699      0.092185           0.239587          0.005298
# VolBrain       0.235907      0.089032           0.236713          0.007968
# rest           0.175264      0.201208           0.176256          0.019923
# set1           0.307363      0.075988           0.307811          0.029990
# set2           0.243897      0.100109           0.244428          0.039668
# set3           0.275159      0.068151           0.275712          0.010646
# set4           0.206888      0.140162           0.207424          0.022173
# set5           0.263325      0.102342           0.264140          0.041261
# set6           0.306457      0.076108           0.306804          0.030305
# set7           0.284731      0.068812           0.285372          0.012918
# set8           0.214289      0.131828           0.215248          0.024354
#
# Correlation
#           R_1_age_pred  R_1_age_gap  R_1_age_pred_cor  R_1_age_gap_cor
# carit1       -0.228638    -0.527366         -0.237748        -0.190108
# carit3       -0.319272    -0.478285         -0.324903        -0.169785
# carit4       -0.227287    -0.517513         -0.230190        -0.150203
# face1        -0.343845    -0.447212         -0.338122        -0.110916
# face2        -0.340146    -0.446543         -0.343810        -0.118749
# face3        -0.336255    -0.473272         -0.339226        -0.077971
# face4        -0.209361    -0.522147         -0.210674        -0.163668
# face5        -0.407916    -0.407010         -0.408168        -0.087930
# face6        -0.418519    -0.408233         -0.407569        -0.049710
# vism         -0.360266    -0.442267         -0.363511        -0.112533
# carit_FC     -0.421644    -0.457760         -0.425550        -0.114537
# face_FC      -0.433029    -0.454888         -0.432479        -0.154020
# vism_FC      -0.403104    -0.456323         -0.404315        -0.124674
# cort         -0.493677    -0.280818         -0.493323        -0.026323
# surf         -0.333125    -0.470265         -0.337175        -0.116151
# subc         -0.486517    -0.303621         -0.489476         0.072785
# VolBrain     -0.485703    -0.298383         -0.486532         0.089265
# rest         -0.418645    -0.448563         -0.419829        -0.141149
# set1         -0.554403    -0.275659         -0.554807        -0.173177
# set2         -0.493859    -0.316400         -0.494397        -0.199168
# set3         -0.524556    -0.261057         -0.525083        -0.103181
# set4         -0.454849    -0.374382         -0.455438        -0.148907
# set5         -0.513152    -0.319910         -0.513946        -0.203129
# set6         -0.553586    -0.275876         -0.553899        -0.174083
# set7         -0.533602    -0.262320         -0.534202        -0.113656
# set8         -0.462914    -0.363082         -0.463948        -0.156057
#
# Pvalue for correlation
#           Pval_1_age_pred  Pval_1_age_gap  Pval_1_age_pred_cor  \
# carit1           0.000000             0.0             0.000000
# carit3           0.000000             0.0             0.000000
# carit4           0.000000             0.0             0.000000
# face1            0.000000             0.0             0.000000
# face2            0.000000             0.0             0.000000
# face3            0.000000             0.0             0.000000
# face4            0.000002             0.0             0.000002
# face5            0.000000             0.0             0.000000
# face6            0.000000             0.0             0.000000
# vism             0.000000             0.0             0.000000
# carit_FC         0.000000             0.0             0.000000
# face_FC          0.000000             0.0             0.000000
# vism_FC          0.000000             0.0             0.000000
# cort             0.000000             0.0             0.000000
# surf             0.000000             0.0             0.000000
# subc             0.000000             0.0             0.000000
# VolBrain         0.000000             0.0             0.000000
# rest             0.000000             0.0             0.000000
# set1             0.000000             0.0             0.000000
# set2             0.000000             0.0             0.000000
# set3             0.000000             0.0             0.000000
# set4             0.000000             0.0             0.000000
# set5             0.000000             0.0             0.000000
# set6             0.000000             0.0             0.000000
# set7             0.000000             0.0             0.000000
# set8             0.000000             0.0             0.000000
#
#           Pval_1_age_gap_cor
# carit1              0.000017
# carit3              0.000128
# carit4              0.000717
# face1               0.012718
# face2               0.007613
# face3               0.080331
# face4               0.000224
# face5               0.048503
# face6               0.265320
# vism                0.011468
# carit_FC            0.010069
# face_FC             0.000521
# vism_FC             0.005064
# cort                0.555473
# surf                0.009056
# subc                0.102652
# VolBrain            0.045174
# rest                0.001489
# set1                0.000093
# set2                0.000007
# set3                0.020512
# set4                0.000798
# set5                0.000004
# set6                0.000085
# set7                0.010664
# set8                0.000438

# %%
#Predicting cognition with age and predicted age index

#two predictors (one of brain age indexes and real age)

dct_r2_two = {}
dct_u1_two = {}
dct_u2_two = {}
dct_c_two = {}

for dset, dset_name in zip([age_pred, age_gap, age_pred_cor, age_gap_cor], 
                           ['age_pred', 'age_gap', 'age_pred_cor', 'age_gap_cor']):  
    #
    dct_r2_two[dset_name] = {}
    dct_u1_two[dset_name] = {}
    dct_u2_two[dset_name] = {}
    dct_c_two[dset_name] = {}
    
    for col in dset.columns:
        #
        r2_i = get_r2(dset[col], cog_orig)
        r2_j = get_r2(pd.concat([age_orig, age_orig_sqrd], axis=1), cog_orig) ###
        r2_ij = get_r2(pd.concat([dset[col], pd.concat([age_orig, age_orig_sqrd], axis=1)], axis=1), cog_orig) ###

        u_i = r2_ij - r2_j
        u_j = r2_ij - r2_i

        c_ij = r2_ij - u_i - u_j
        
        dct_r2_two[dset_name][col] = r2_ij
        dct_u1_two[dset_name][col] = u_i
        dct_u2_two[dset_name][col] = u_j
        dct_c_two[dset_name][col] = c_ij
        
    dct_r2_two[dset_name] = pd.Series(dct_r2_two[dset_name])
    dct_u1_two[dset_name] = pd.Series(dct_u1_two[dset_name])
    dct_u2_two[dset_name] = pd.Series(dct_u2_two[dset_name])
    dct_c_two[dset_name] = pd.Series(dct_c_two[dset_name])


df_r2_two = pd.DataFrame(dct_r2_two)
df_r2_two.columns = ['r2_2_'+i+"+age-orig" for i in df_r2_two.columns]
df_u1_two = pd.DataFrame(dct_u1_two)
df_u1_two.columns = ['U_2_'+i for i in df_u1_two.columns]

df_u2_two = pd.DataFrame(dct_u2_two)
df_u2_two.columns = ['U_2_age-orig_('+i+')' for i in df_u2_two.columns]

df_c_two = pd.DataFrame(dct_c_two)
df_c_two.columns = ['C_2_'+i+'+age-orig' for i in df_c_two.columns]

print('Two predictors for cognition prediction')
print('R2, uniq R2, common R2')
display(pd.concat([df_r2_two, df_u1_two, df_u2_two, df_c_two], axis=1) )
# Out:
# Two predictors for cognition prediction
# R2, uniq R2, common R2
#           r2_2_age_pred+age-orig  r2_2_age_gap+age-orig  \
# carit1                  0.328423               0.328423
# carit3                  0.327498               0.327498
# carit4                  0.325613               0.325613
# face1                   0.329897               0.329897
# face2                   0.327491               0.327491
# face3                   0.334236               0.334236
# face4                   0.325604               0.325604
# face5                   0.333690               0.333690
# face6                   0.341893               0.341893
# vism                    0.331203               0.331203
# carit_FC                0.328163               0.328163
# face_FC                 0.330473               0.330473
# vism_FC                 0.330354               0.330354
# cort                    0.326980               0.326980
# surf                    0.326991               0.326991
# subc                    0.332706               0.332706
# VolBrain                0.333884               0.333884
# rest                    0.325599               0.325599
# set1                    0.341052               0.341052
# set2                    0.341677               0.341677
# set3                    0.328859               0.328859
# set4                    0.331173               0.331173
# set5                    0.342802               0.342802
# set6                    0.340700               0.340700
# set7                    0.331539               0.331539
# set8                    0.328549               0.328549
#
#           r2_2_age_pred_cor+age-orig  r2_2_age_gap_cor+age-orig  U_2_age_pred  \
# carit1                      0.328405                   0.328405      0.002911
# carit3                      0.327407                   0.327407      0.001986
# carit4                      0.325620                   0.325620      0.000101
# face1                       0.328523                   0.328523      0.004385
# face2                       0.327637                   0.327637      0.001978
# face3                       0.334670                   0.334670      0.008724
# face4                       0.325904                   0.325904      0.000092
# face5                       0.332891                   0.332891      0.008178
# face6                       0.337431                   0.337431      0.016381
# vism                        0.330927                   0.330927      0.005691
# carit_FC                    0.328688                   0.328688      0.002651
# face_FC                     0.329839                   0.329839      0.004961
# vism_FC                     0.329621                   0.329621      0.004841
# cort                        0.326866                   0.326866      0.001468
# surf                        0.326778                   0.326778      0.001479
# subc                        0.333025                   0.333025      0.007194
# VolBrain                    0.333887                   0.333887      0.008372
# rest                        0.325579                   0.325579      0.000086
# set1                        0.341091                   0.341091      0.015540
# set2                        0.341596                   0.341596      0.016165
# set3                        0.328868                   0.328868      0.003347
# set4                        0.331095                   0.331095      0.005661
# set5                        0.342799                   0.342799      0.017290
# set6                        0.340687                   0.340687      0.015188
# set7                        0.331596                   0.331596      0.006027
# set8                        0.328555                   0.328555      0.003037
#
#           U_2_age_gap  U_2_age_pred_cor  U_2_age_gap_cor  \
# carit1       0.002911          0.002892         0.002892
# carit3       0.001986          0.001895         0.001895
# carit4       0.000101          0.000107         0.000107
# face1        0.004385          0.003011         0.003011
# face2        0.001978          0.002125         0.002125
# face3        0.008724          0.009157         0.009157
# face4        0.000092          0.000392         0.000392
# face5        0.008178          0.007379         0.007379
# face6        0.016381          0.011919         0.011919
# vism         0.005691          0.005414         0.005414
# carit_FC     0.002651          0.003175         0.003175
# face_FC      0.004961          0.004326         0.004326
# vism_FC      0.004841          0.004109         0.004109
# cort         0.001468          0.001354         0.001354
# surf         0.001479          0.001266         0.001266
# subc         0.007194          0.007513         0.007513
# VolBrain     0.008372          0.008374         0.008374
# rest         0.000086          0.000066         0.000066
# set1         0.015540          0.015579         0.015579
# set2         0.016165          0.016084         0.016084
# set3         0.003347          0.003356         0.003356
# set4         0.005661          0.005582         0.005582
# set5         0.017290          0.017287         0.017287
# set6         0.015188          0.015175         0.015175
# set7         0.006027          0.006084         0.006084
# set8         0.003037          0.003043         0.003043
#
#           U_2_age-orig_(age_pred)  U_2_age-orig_(age_gap)  \
# carit1                   0.276148                0.050309
# carit3                   0.225564                0.098742
# carit4                   0.273954                0.057794
# face1                    0.211668                0.129899
# face2                    0.211792                0.128090
# face3                    0.221169                0.110250
# face4                    0.281772                0.052966
# face5                    0.167295                0.168033
# face6                    0.166735                0.175239
# vism                     0.201412                0.135603
# carit_FC                 0.150380                0.118619
# face_FC                  0.142959                0.123549
# vism_FC                  0.167861                0.122123
# cort                     0.083263                0.248121
# surf                     0.216019                0.105842
# subc                     0.096007                0.240521
# VolBrain                 0.097977                0.244852
# rest                     0.150335                0.124390
# set1                     0.033689                0.265064
# set2                     0.097780                0.241568
# set3                     0.053700                0.260708
# set4                     0.124285                0.191011
# set5                     0.079477                0.240460
# set6                     0.034243                0.264592
# set7                     0.046808                0.262728
# set8                     0.114260                0.196721
#
#           U_2_age-orig_(age_pred_cor)  U_2_age-orig_(age_gap_cor)  \
# carit1                       0.271881                    0.292264
# carit3                       0.221845                    0.298580
# carit4                       0.272632                    0.303059
# face1                        0.214196                    0.316221
# face2                        0.209432                    0.313536
# face3                        0.219596                    0.328590
# face4                        0.281521                    0.299117
# face5                        0.166290                    0.325159
# face6                        0.171318                    0.334960
# vism                         0.198786                    0.318263
# carit_FC                     0.147595                    0.315569
# face_FC                      0.142801                    0.306117
# vism_FC                      0.166151                    0.314078
# cort                         0.083499                    0.326173
# surf                         0.213091                    0.313287
# subc                         0.093438                    0.327727
# VolBrain                     0.097174                    0.325918
# rest                         0.149322                    0.305656
# set1                         0.033280                    0.311101
# set2                         0.097168                    0.301928
# set3                         0.053156                    0.318222
# set4                         0.123671                    0.308921
# set5                         0.078659                    0.301538
# set6                         0.033882                    0.310382
# set7                         0.046224                    0.318678
# set8                         0.113307                    0.304202
#
#           C_2_age_pred+age-orig  C_2_age_gap+age-orig  \
# carit1                 0.049365              0.275204
# carit3                 0.099949              0.226770
# carit4                 0.051558              0.267718
# face1                  0.113844              0.195613
# face2                  0.113721              0.197422
# face3                  0.104344              0.215263
# face4                  0.043740              0.272546
# face5                  0.158218              0.157480
# face6                  0.158778              0.150274
# vism                   0.124101              0.189909
# carit_FC               0.175132              0.206893
# face_FC                0.182553              0.201963
# vism_FC                0.157652              0.203389
# cort                   0.242249              0.077391
# surf                   0.109493              0.219670
# subc                   0.229505              0.084992
# VolBrain               0.227535              0.080660
# rest                   0.175178              0.201122
# set1                   0.291823              0.060448
# set2                   0.227733              0.083944
# set3                   0.271813              0.064804
# set4                   0.201227              0.134501
# set5                   0.246035              0.085053
# set6                   0.291269              0.060920
# set7                   0.278704              0.062785
# set8                   0.211252              0.128792
#
#           C_2_age_pred_cor+age-orig  C_2_age_gap_cor+age-orig
# carit1                     0.053632                  0.033249
# carit3                     0.103667                  0.026932
# carit4                     0.052880                  0.022454
# face1                      0.111316                  0.009292
# face2                      0.116080                  0.011976
# face3                      0.105917                 -0.003078
# face4                      0.043992                  0.026395
# face5                      0.159223                  0.000353
# face6                      0.154194                 -0.009447
# vism                       0.126726                  0.007249
# carit_FC                   0.177917                  0.009943
# face_FC                    0.182712                  0.019396
# vism_FC                    0.159361                  0.011434
# cort                       0.242013                 -0.000661
# surf                       0.112421                  0.012225
# subc                       0.232074                 -0.002215
# VolBrain                   0.228339                 -0.000406
# rest                       0.176190                  0.019857
# set1                       0.292232                  0.014412
# set2                       0.228344                  0.023584
# set3                       0.272356                  0.007290
# set4                       0.201842                  0.016591
# set5                       0.246854                  0.023975
# set6                       0.291630                  0.015130
# set7                       0.279288                  0.006834
# set8                       0.212205                  0.021311

# %%
X = pd.concat([dset[col], pd.concat([age_orig, age_orig_sqrd], axis=1)], axis=1)
y = cog_orig
linreg = LinearRegression()
linreg.fit(StandardScaler().fit_transform(X.values), y).score(StandardScaler().fit_transform(X.values), y)
# Out:
# 0.32855546283793213

# %%
linreg.coef_
# Out:
# array([ 0.74164959,  0.0290279 , -7.4090419 ])

# %%
linreg.intercept_
# Out:
# 100.03373015873017

# %%
#Predicting cognition with age, predicted age index and predicted cognition

#three predictors (one of brain age indexes, real age, predicted cognition)

dct_r2_one_cog = {}
dct_r2_two_age_cogpr = {}
dct_r2_two_agepr_cogpr = {}
dct_r2_three = {}

dct_u1_three = {}
dct_u2_three = {}
dct_u3_three = {}

dct_c1_three = {}
dct_c2_three = {}
dct_c3_three = {}
dct_c4_three = {}

for dset, dset_name in zip([age_pred, age_gap, age_pred_cor, age_gap_cor], 
                           ['age_pred', 'age_gap', 'age_pred_cor', 'age_gap_cor']):  
    #
    dct_r2_one_cog[dset_name] = {}
    dct_r2_two_age_cogpr[dset_name] = {}
    dct_r2_two_agepr_cogpr[dset_name] = {}
    dct_r2_three[dset_name] = {}

    dct_u1_three[dset_name] = {}
    dct_u2_three[dset_name] = {}
    dct_u3_three[dset_name] = {}

    dct_c1_three[dset_name] = {}
    dct_c2_three[dset_name] = {}
    dct_c3_three[dset_name] = {}
    dct_c4_three[dset_name] = {}
    
    for col in dset.columns:
        #
        r2_i = get_r2( dset[col], cog_orig)
        r2_j = get_r2( pd.concat([age_orig, age_orig_sqrd], axis=1), cog_orig)
        r2_k = get_r2( cog_pred[col], cog_orig) #

        r2_jk = get_r2( pd.concat([ pd.concat([age_orig, age_orig_sqrd], axis=1), cog_pred[col]],axis=1), cog_orig) #
        r2_ik = get_r2( pd.concat([ dset[col], cog_pred[col]],axis=1), cog_orig) #
        r2_ij = get_r2( pd.concat([ dset[col],pd.concat([age_orig, age_orig_sqrd], axis=1)],axis=1), cog_orig)

        r2_ijk = get_r2( pd.concat([ dset[col], pd.concat([age_orig, age_orig_sqrd], axis=1), cog_pred[col] ],axis=1), cog_orig) #

        u_i = r2_ijk - r2_jk # uniq for age_predicted
        u_j = r2_ijk - r2_ik # uniq for age
        u_k = r2_ijk - r2_ij # uniq for cog predicted

        c_ij = r2_ik + r2_jk - r2_k - r2_ijk
        c_ik = r2_ij + r2_jk - r2_j - r2_ijk
        c_jk = r2_ij + r2_ik - r2_i - r2_ijk
        c_ijk = r2_i + r2_j + r2_k - r2_ij - r2_ik - r2_jk + r2_ijk
        
        
        dct_r2_one_cog[dset_name][col] = r2_k
        dct_r2_two_age_cogpr[dset_name][col] = r2_jk
        dct_r2_two_agepr_cogpr[dset_name][col] = r2_ik
        dct_r2_three[dset_name][col] = r2_ijk

        dct_u1_three[dset_name][col] = u_i
        dct_u2_three[dset_name][col] = u_j
        dct_u3_three[dset_name][col] = u_k

        dct_c1_three[dset_name][col] = c_ij
        dct_c2_three[dset_name][col] = c_ik
        dct_c3_three[dset_name][col] = c_jk
        dct_c4_three[dset_name][col] = c_ijk
    
    dct_r2_one_cog[dset_name] = pd.Series(dct_r2_one_cog[dset_name])
    dct_r2_two_age_cogpr[dset_name] = pd.Series(dct_r2_two_age_cogpr[dset_name])
    dct_r2_two_agepr_cogpr[dset_name] = pd.Series(dct_r2_two_agepr_cogpr[dset_name])
    dct_r2_three[dset_name] = pd.Series(dct_r2_three[dset_name])

    dct_u1_three[dset_name] = pd.Series(dct_u1_three[dset_name])
    dct_u2_three[dset_name] = pd.Series(dct_u2_three[dset_name])
    dct_u3_three[dset_name] = pd.Series(dct_u3_three[dset_name])

    dct_c1_three[dset_name] = pd.Series(dct_c1_three[dset_name])
    dct_c2_three[dset_name] = pd.Series(dct_c2_three[dset_name])
    dct_c3_three[dset_name] = pd.Series(dct_c3_three[dset_name])
    dct_c4_three[dset_name] = pd.Series(dct_c4_three[dset_name])

df_r2_one_cog = pd.DataFrame(dct_r2_one_cog['age_pred'])
df_r2_one_cog.columns = ['r2_1_cog_pred']
df_r2_two_age_cogpr = pd.DataFrame(dct_r2_two_age_cogpr['age_pred'])
df_r2_two_age_cogpr.columns = ['r2_3_2_age-orig+cog-pred']
df_r2_two_agepr_cogpr = pd.DataFrame(dct_r2_two_agepr_cogpr)
df_r2_two_agepr_cogpr.columns = ['r2_3_2_'+i+'+cog-pred' for i in df_r2_two_agepr_cogpr.columns]
df_r2_three = pd.DataFrame(dct_r2_three)
df_r2_three.columns = ['r2_3_'+i+'+age+cog-pred' for i in df_r2_three.columns]

df_u1_three = pd.DataFrame(dct_u1_three)
df_u1_three.columns = ['U_3_'+i for i in df_u1_three.columns]
df_u2_three = pd.DataFrame(dct_u2_three)
df_u2_three.columns = ['U_3_age-orig_('+i+')' for i in df_u2_three.columns]
df_u3_three = pd.DataFrame(dct_u3_three)
df_u3_three.columns = ['U_3_cog-pred_('+i+')' for i in df_u3_three.columns]

df_c1_three = pd.DataFrame(dct_c1_three)
df_c1_three.columns = ['C_3_2_'+i+'+age-orig' for i in df_c1_three.columns]
df_c2_three = pd.DataFrame(dct_c2_three)
df_c2_three.columns = ['C_3_2_'+i+'+cog-pred' for i in df_c2_three.columns]
df_c3_three = pd.DataFrame(dct_c3_three)
df_c3_three.columns = ['C_3_2_age-orig+cog-pred_('+i+')' for i in df_c3_three.columns]
df_c4_three = pd.DataFrame(dct_c4_three)
df_c4_three.columns = ['C_3_'+i+'+age+cog-pred' for i in df_c4_three.columns]


print('Three predictors for cognition prediction')
print('R2, uniq R2, common R2')
display(pd.concat([df_r2_one_cog, df_r2_two_age_cogpr, df_r2_two_agepr_cogpr, df_r2_three,
                   df_u1_three, df_u2_three, df_u3_three, 
                   df_c1_three, df_c2_three, df_c3_three, df_c4_three], axis=1))
# Out:
# Three predictors for cognition prediction
# R2, uniq R2, common R2
#           r2_1_cog_pred  r2_3_2_age-orig+cog-pred  r2_3_2_age_pred+cog-pred  \
# carit1         0.031342                  0.329341                  0.054341
# carit3         0.090492                  0.333756                  0.113506
# carit4         0.058000                  0.331967                  0.068259
# face1          0.171927                  0.368133                  0.176301
# face2          0.182768                  0.369828                  0.184428
# face3          0.192793                  0.393593                  0.194318
# face4          0.077471                  0.336969                  0.077944
# face5          0.242093                  0.396043                  0.246551
# face6          0.244930                  0.404759                  0.251011
# vism           0.166127                  0.371461                  0.175292
# carit_FC       0.183767                  0.340601                  0.195598
# face_FC        0.274222                  0.392339                  0.275187
# vism_FC        0.189582                  0.348396                  0.194894
# cort           0.275058                  0.345279                  0.277745
# surf           0.107584                  0.341218                  0.130382
# subc           0.230942                  0.341181                  0.245373
# VolBrain       0.232451                  0.337698                  0.238999
# rest           0.261991                  0.381709                  0.262846
# set1           0.392952                  0.446874                  0.406278
# set2           0.330498                  0.427038                  0.335914
# set3           0.351679                  0.397018                  0.355634
# set4           0.284139                  0.382001                  0.284140
# set5           0.343795                  0.429555                  0.350285
# set6           0.389290                  0.443302                  0.402293
# set7           0.373097                  0.412906                  0.375907
# set8           0.320242                  0.399233                  0.321056
#
#           r2_3_2_age_gap+cog-pred  r2_3_2_age_pred_cor+cog-pred  \
# carit1                   0.304384                      0.058259
# carit3                   0.305662                      0.116203
# carit4                   0.313653                      0.069583
# face1                    0.365313                      0.175386
# face2                    0.379790                      0.184889
# face3                    0.397348                      0.194816
# face4                    0.342830                      0.078576
# face5                    0.398856                      0.246583
# face6                    0.401657                      0.249501
# vism                     0.366240                      0.176300
# carit_FC                 0.333548                      0.197376
# face_FC                  0.410177                      0.275461
# vism_FC                  0.344676                      0.194941
# cort                     0.352077                      0.277721
# surf                     0.316337                      0.132428
# subc                     0.323279                      0.247505
# VolBrain                 0.325434                      0.239582
# rest                     0.414967                      0.263006
# set1                     0.450426                      0.406408
# set2                     0.434749                      0.336074
# set3                     0.408732                      0.355794
# set4                     0.401523                      0.284148
# set5                     0.439811                      0.350517
# set6                     0.446797                      0.402413
# set7                     0.425754                      0.376016
# set8                     0.434382                      0.320959
#
#           r2_3_2_age_gap_cor+cog-pred  r2_3_age_pred+age+cog-pred  \
# carit1                       0.118486                    0.329793
# carit3                       0.193529                    0.334084
# carit4                       0.135741                    0.333816
# face1                        0.287769                    0.376495
# face2                        0.309377                    0.386082
# face3                        0.301575                    0.403944
# face4                        0.198560                    0.348357
# face5                        0.349168                    0.408142
# face6                        0.342595                    0.411548
# vism                         0.283919                    0.379535
# carit_FC                     0.287509                    0.344394
# face_FC                      0.391513                    0.413601
# vism_FC                      0.306804                    0.352803
# cort                         0.342407                    0.355808
# surf                         0.191164                    0.343443
# subc                         0.289853                    0.342075
# VolBrain                     0.308797                    0.338328
# rest                         0.394999                    0.419495
# set1                         0.446201                    0.456462
# set2                         0.427556                    0.440569
# set3                         0.403474                    0.413000
# set4                         0.396261                    0.405302
# set5                         0.434759                    0.443778
# set6                         0.442673                    0.452952
# set7                         0.422492                    0.428976
# set8                         0.436418                    0.440302
#
#           r2_3_age_gap+age+cog-pred  r2_3_age_pred_cor+age+cog-pred  \
# carit1                     0.329793                        0.329818
# carit3                     0.334084                        0.334109
# carit4                     0.333816                        0.333615
# face1                      0.376495                        0.379244
# face2                      0.386082                        0.385512
# face3                      0.403944                        0.402992
# face4                      0.348357                        0.349323
# face5                      0.408142                        0.409501
# face6                      0.411548                        0.415020
# vism                       0.379535                        0.379905
# carit_FC                   0.344394                        0.343487
# face_FC                    0.413601                        0.413724
# vism_FC                    0.352803                        0.354180
# cort                       0.355808                        0.356134
# surf                       0.343443                        0.343670
# subc                       0.342075                        0.341801
# VolBrain                   0.338328                        0.338296
# rest                       0.419495                        0.419742
# set1                       0.456462                        0.456474
# set2                       0.440569                        0.440596
# set3                       0.413000                        0.412853
# set4                       0.405302                        0.405273
# set5                       0.443778                        0.443756
# set6                       0.452952                        0.452978
# set7                       0.428976                        0.428888
# set8                       0.440302                        0.440365
#
#           r2_3_age_gap_cor+age+cog-pred  ...  C_3_2_age_pred_cor+cog-pred  \
# carit1                         0.329818  ...                     0.002415
# carit3                         0.334109  ...                     0.001541
# carit4                         0.333615  ...                    -0.001540
# face1                          0.379244  ...                    -0.008100
# face2                          0.385512  ...                    -0.013559
# face3                          0.402992  ...                    -0.000242
# face4                          0.349323  ...                    -0.011962
# face5                          0.409501  ...                    -0.006079
# face6                          0.415020  ...                     0.001658
# vism                           0.379905  ...                    -0.003030
# carit_FC                       0.343487  ...                     0.000290
# face_FC                        0.413724  ...                    -0.017058
# vism_FC                        0.354180  ...                    -0.001674
# cort                           0.356134  ...                    -0.009501
# surf                           0.343670  ...                    -0.001187
# subc                           0.341801  ...                     0.006893
# VolBrain                       0.338296  ...                     0.007776
# rest                           0.419742  ...                    -0.037966
# set1                           0.456474  ...                     0.005979
# set2                           0.440596  ...                     0.002526
# set3                           0.412853  ...                    -0.012480
# set4                           0.405273  ...                    -0.017689
# set5                           0.443756  ...                     0.003085
# set6                           0.452978  ...                     0.005498
# set7                           0.428888  ...                    -0.009898
# set8                           0.440365  ...                    -0.038089
#
#           C_3_2_age_gap_cor+cog-pred  C_3_2_age-orig+cog-pred_(age_pred)  \
# carit1                      0.002415                            0.000696
# carit3                      0.001541                            0.004985
# carit4                     -0.001540                            0.008397
# face1                      -0.008100                            0.011474
# face2                      -0.013559                            0.010137
# face3                      -0.000242                            0.011543
# face4                      -0.011962                            0.011359
# face5                      -0.006079                            0.005704
# face6                       0.001658                            0.006197
# vism                       -0.003030                           -0.002831
# carit_FC                    0.000290                            0.001584
# face_FC                    -0.017058                            0.004546
# vism_FC                    -0.001674                            0.009952
# cort                       -0.009501                            0.005200
# surf                       -0.001187                            0.002958
# subc                        0.006893                           -0.000695
# VolBrain                    0.007776                           -0.001353
# rest                       -0.037966                           -0.006313
# set1                        0.005979                           -0.016495
# set2                        0.002526                           -0.006875
# set3                       -0.012480                           -0.003666
# set4                       -0.017689                            0.003124
# set5                        0.003085                           -0.014016
# set6                        0.005498                           -0.016415
# set7                       -0.009898                           -0.006261
# set8                       -0.038089                           -0.004987
#
#           C_3_2_age-orig+cog-pred_(age_gap)  \
# carit1                             0.024900
# carit3                             0.070320
# carit4                             0.037631
# face1                              0.118718
# face2                              0.121798
# face3                              0.103654
# face4                              0.047439
# face5                              0.158747
# face6                              0.165347
# vism                               0.122309
# carit_FC                           0.107773
# face_FC                            0.120125
# vism_FC                            0.113997
# cort                               0.244390
# surf                               0.078736
# subc                               0.221724
# VolBrain                           0.231958
# rest                               0.119863
# set1                               0.259028
# set2                               0.235748
# set3                               0.256441
# set4                               0.187232
# set5                               0.236493
# set6                               0.258438
# set7                               0.259506
# set8                               0.190800
#
#           C_3_2_age-orig+cog-pred_(age_pred_cor)  \
# carit1                                  0.000322
# carit3                                  0.003939
# carit4                                  0.008600
# face1                                   0.010338
# face2                                   0.008810
# face3                                   0.011419
# face4                                   0.010773
# face5                                   0.003372
# face6                                   0.005800
# vism                                   -0.004819
# carit_FC                                0.001485
# face_FC                                 0.004537
# vism_FC                                 0.006912
# cort                                    0.005086
# surf                                    0.001850
# subc                                   -0.000857
# VolBrain                               -0.001541
# rest                                   -0.007414
# set1                                   -0.016786
# set2                                   -0.007353
# set3                                   -0.003904
# set4                                    0.002546
# set5                                   -0.014580
# set6                                   -0.016683
# set7                                   -0.006647
# set8                                   -0.006099
#
#           C_3_2_age-orig+cog-pred_(age_gap_cor)  C_3_age_pred+age+cog-pred  \
# carit1                                 0.080931                   0.026817
# carit3                                 0.157999                   0.077263
# carit4                                 0.105185                   0.043149
# face1                                  0.224745                   0.117832
# face2                                  0.237401                   0.128315
# face3                                  0.227173                   0.113170
# face4                                  0.148354                   0.054655
# face5                                  0.264827                   0.165858
# face6                                  0.262535                   0.159486
# vism                                   0.222277                   0.123009
# carit_FC                               0.259592                   0.167094
# face_FC                                0.283905                   0.202849
# vism_FC                                0.266702                   0.156746
# cort                                   0.312446                   0.250092
# surf                                   0.160781                   0.088920
# subc                                   0.275779                   0.215969
# VolBrain                               0.296419                   0.221618
# rest                                   0.280913                   0.212107
# set1                                   0.300828                   0.288086
# set2                                   0.288888                   0.235847
# set3                                   0.308842                   0.283840
# set4                                   0.299909                   0.224527
# set5                                   0.292541                   0.253769
# set6                                   0.300077                   0.287917
# set7                                   0.312282                   0.291964
# set8                                   0.300255                   0.251508
#
#           C_3_age_gap+age+cog-pred  C_3_age_pred_cor+age+cog-pred  \
# carit1                    0.002613                       0.027191
# carit3                    0.011928                       0.078309
# carit4                    0.013914                       0.042945
# face1                     0.010588                       0.118968
# face2                     0.016654                       0.129643
# face3                     0.021059                       0.113294
# face4                     0.018575                       0.055240
# face5                     0.012815                       0.168190
# face6                     0.000336                       0.159884
# vism                     -0.002130                       0.124997
# carit_FC                  0.060905                       0.167193
# face_FC                   0.087269                       0.202858
# vism_FC                   0.052702                       0.159787
# cort                      0.010902                       0.250206
# surf                      0.013142                       0.090029
# subc                     -0.006451                       0.216131
# VolBrain                 -0.011692                       0.221806
# rest                      0.085931                       0.213208
# set1                      0.012563                       0.288376
# set2                     -0.006776                       0.236325
# set3                      0.023733                       0.284078
# set4                      0.040418                       0.225105
# set5                      0.003260                       0.254333
# set6                      0.013063                       0.288184
# set7                      0.026197                       0.292351
# set8                      0.055722                       0.252621
#
#           C_3_age_gap_cor+age+cog-pred
# carit1                       -0.053419
# carit3                       -0.075751
# carit4                       -0.053640
# face1                        -0.095439
# face2                        -0.098949
# face3                        -0.102460
# face4                        -0.082340
# face5                        -0.093264
# face6                        -0.096852
# vism                         -0.102098
# carit_FC                     -0.090914
# face_FC                      -0.076510
# vism_FC                      -0.100004
# cort                         -0.057155
# surf                         -0.068903
# subc                         -0.060506
# VolBrain                     -0.076154
# rest                         -0.075119
# set1                         -0.029238
# set2                         -0.059916
# set3                         -0.028668
# set4                         -0.072259
# set5                         -0.052788
# set6                         -0.028576
# set7                         -0.026579
# set8                         -0.053733
#
# [26 rows x 38 columns]

# %%
X = pd.concat([ dset[col], pd.concat([age_orig, age_orig_sqrd], axis=1), cog_pred[col] ],axis=1)
y = cog_orig
linreg = LinearRegression()
linreg.fit(StandardScaler().fit_transform(X.values), y).score(StandardScaler().fit_transform(X.values), y)
# Out:
# 0.4403647620376566

# %%
linreg.coef_
# Out:
# array([-3.93413528,  4.81345322, -5.57089471,  7.81419732])

# %%
linreg.intercept_
# Out:
# 100.03373015873017

# %%
#add extra columns from ML

dct_age_brain={}
for col in age_pred.columns:
    dct_age_brain[col] = get_r2( age_pred[col], age_orig)
    
age_brain = pd.Series(dct_age_brain)
age_brain.name = 'r2_AGE_brain'

cog_brain = df_r2_one_cog['r2_1_cog_pred']
cog_brain.name = 'r2_COG_brain'

# %%
#assemble into one big table and save

big_table = pd.concat([cog_brain, age_brain, df_r2_one, 
                       df_r2_two, df_u1_two, df_u2_two, df_c_two,
                       df_r2_two_age_cogpr, df_r2_two_agepr_cogpr, df_r2_three,
                       df_u1_three, df_u2_three, df_u3_three, 
                       df_c1_three, df_c2_three, df_c3_three, df_c4_three], axis=1)
big_table.index = ['carit1-allNoGo-allGo', 'carit3-allGo', 'carit4-allNoGo', 'face1-encoding', 'face2-recall', 'face3-distractor', 'face4-encoding-recall',
                   'face5-encoding-distractor', 'face6-recall-distractor', 'VisualMotor', 'carit_FC', 'face_FC', 'vism_FC', 'cort_thickness',
                   'cort_surface', 'subcortex', 'Total_Brain_Volume', 'Resting_State_FC_75PC', 
                   'All-Modality_con+FC(set1)', 'Task_con(set2)', 'Non-Task(set3)', 
                   'Task_FC(set4)', 'Task_con+FC(set5)', 'All-modality_con(set6)', 
                   'All-modality_FC(set7)', 'FC_rest_task(set8)']
display(big_table)

#save
big_table.to_csv(path+'commonality_cog_fluid_age2.csv')
# Out:
#                            r2_COG_brain  r2_AGE_brain  r2_1_age_pred  \
# carit1-allNoGo-allGo           0.031342      0.098319       0.052275
# carit3-allGo                   0.090492      0.249086       0.101934
# carit4-allNoGo                 0.058000      0.146194       0.051659
# face1-encoding                 0.171927      0.258833       0.118230
# face2-recall                   0.182768      0.288199       0.115699
# face3-distractor               0.192793      0.203222       0.113068
# face4-encoding-recall          0.077471      0.148571       0.043832
# face5-encoding-distractor      0.242093      0.355701       0.166395
# face6-recall-distractor        0.244930      0.304936       0.175158
# VisualMotor                    0.166127      0.281437       0.129792
# carit_FC                       0.183767      0.482692       0.177783
# face_FC                        0.274222      0.471755       0.187514
# vism_FC                        0.189582      0.399599       0.162493
# cort_thickness                 0.275058      0.693224       0.243717
# cort_surface                   0.107584      0.285431       0.110972
# subcortex                      0.230942      0.575172       0.236699
# Total_Brain_Volume             0.232451      0.562746       0.235907
# Resting_State_FC_75PC          0.261991      0.541438       0.175264
# All-Modality_con+FC(set1)      0.392952      0.765180       0.307363
# Task_con(set2)                 0.330498      0.522033       0.243897
# Non-Task(set3)                 0.351679      0.770564       0.275159
# Task_FC(set4)                  0.284139      0.529021       0.206888
# Task_con+FC(set5)              0.343795      0.585459       0.263325
# All-modality_con(set6)         0.389290      0.763301       0.306457
# All-modality_FC(set7)          0.373097      0.773698       0.284731
# FC_rest_task(set8)             0.320242      0.588753       0.214289
#
#                            r2_1_age_gap  r2_1_age_pred_cor  r2_1_age_gap_cor  \
# carit1-allNoGo-allGo           0.278114           0.056524          0.036141
# carit3-allGo                   0.228756           0.105562          0.028827
# carit4-allNoGo                 0.267819           0.052987          0.022561
# face1-encoding                 0.199998           0.114327          0.012302
# face2-recall                   0.199401           0.118205          0.014101
# face3-distractor               0.223987           0.115074          0.006080
# face4-encoding-recall          0.272638           0.044384          0.026787
# face5-encoding-distractor      0.165657           0.166601          0.007732
# face6-recall-distractor        0.166654           0.166113          0.002471
# VisualMotor                    0.195600           0.132140          0.012664
# carit_FC                       0.209544           0.181093          0.013119
# face_FC                        0.206923           0.187038          0.023722
# vism_FC                        0.208230           0.163470          0.015543
# cort_thickness                 0.078859           0.243367          0.000693
# cort_surface                   0.221149           0.113687          0.013491
# subcortex                      0.092185           0.239587          0.005298
# Total_Brain_Volume             0.089032           0.236713          0.007968
# Resting_State_FC_75PC          0.201208           0.176256          0.019923
# All-Modality_con+FC(set1)      0.075988           0.307811          0.029990
# Task_con(set2)                 0.100109           0.244428          0.039668
# Non-Task(set3)                 0.068151           0.275712          0.010646
# Task_FC(set4)                  0.140162           0.207424          0.022173
# Task_con+FC(set5)              0.102342           0.264140          0.041261
# All-modality_con(set6)         0.076108           0.306804          0.030305
# All-modality_FC(set7)          0.068812           0.285372          0.012918
# FC_rest_task(set8)             0.131828           0.215248          0.024354
#
#                            r2_2_age_pred+age-orig  r2_2_age_gap+age-orig  \
# carit1-allNoGo-allGo                     0.328423               0.328423
# carit3-allGo                             0.327498               0.327498
# carit4-allNoGo                           0.325613               0.325613
# face1-encoding                           0.329897               0.329897
# face2-recall                             0.327491               0.327491
# face3-distractor                         0.334236               0.334236
# face4-encoding-recall                    0.325604               0.325604
# face5-encoding-distractor                0.333690               0.333690
# face6-recall-distractor                  0.341893               0.341893
# VisualMotor                              0.331203               0.331203
# carit_FC                                 0.328163               0.328163
# face_FC                                  0.330473               0.330473
# vism_FC                                  0.330354               0.330354
# cort_thickness                           0.326980               0.326980
# cort_surface                             0.326991               0.326991
# subcortex                                0.332706               0.332706
# Total_Brain_Volume                       0.333884               0.333884
# Resting_State_FC_75PC                    0.325599               0.325599
# All-Modality_con+FC(set1)                0.341052               0.341052
# Task_con(set2)                           0.341677               0.341677
# Non-Task(set3)                           0.328859               0.328859
# Task_FC(set4)                            0.331173               0.331173
# Task_con+FC(set5)                        0.342802               0.342802
# All-modality_con(set6)                   0.340700               0.340700
# All-modality_FC(set7)                    0.331539               0.331539
# FC_rest_task(set8)                       0.328549               0.328549
#
#                            r2_2_age_pred_cor+age-orig  \
# carit1-allNoGo-allGo                         0.328405
# carit3-allGo                                 0.327407
# carit4-allNoGo                               0.325620
# face1-encoding                               0.328523
# face2-recall                                 0.327637
# face3-distractor                             0.334670
# face4-encoding-recall                        0.325904
# face5-encoding-distractor                    0.332891
# face6-recall-distractor                      0.337431
# VisualMotor                                  0.330927
# carit_FC                                     0.328688
# face_FC                                      0.329839
# vism_FC                                      0.329621
# cort_thickness                               0.326866
# cort_surface                                 0.326778
# subcortex                                    0.333025
# Total_Brain_Volume                           0.333887
# Resting_State_FC_75PC                        0.325579
# All-Modality_con+FC(set1)                    0.341091
# Task_con(set2)                               0.341596
# Non-Task(set3)                               0.328868
# Task_FC(set4)                                0.331095
# Task_con+FC(set5)                            0.342799
# All-modality_con(set6)                       0.340687
# All-modality_FC(set7)                        0.331596
# FC_rest_task(set8)                           0.328555
#
#                            r2_2_age_gap_cor+age-orig  ...  \
# carit1-allNoGo-allGo                        0.328405  ...
# carit3-allGo                                0.327407  ...
# carit4-allNoGo                              0.325620  ...
# face1-encoding                              0.328523  ...
# face2-recall                                0.327637  ...
# face3-distractor                            0.334670  ...
# face4-encoding-recall                       0.325904  ...
# face5-encoding-distractor                   0.332891  ...
# face6-recall-distractor                     0.337431  ...
# VisualMotor                                 0.330927  ...
# carit_FC                                    0.328688  ...
# face_FC                                     0.329839  ...
# vism_FC                                     0.329621  ...
# cort_thickness                              0.326866  ...
# cort_surface                                0.326778  ...
# subcortex                                   0.333025  ...
# Total_Brain_Volume                          0.333887  ...
# Resting_State_FC_75PC                       0.325579  ...
# All-Modality_con+FC(set1)                   0.341091  ...
# Task_con(set2)                              0.341596  ...
# Non-Task(set3)                              0.328868  ...
# Task_FC(set4)                               0.331095  ...
# Task_con+FC(set5)                           0.342799  ...
# All-modality_con(set6)                      0.340687  ...
# All-modality_FC(set7)                       0.331596  ...
# FC_rest_task(set8)                          0.328555  ...
#
#                            C_3_2_age_pred_cor+cog-pred  \
# carit1-allNoGo-allGo                          0.002415
# carit3-allGo                                  0.001541
# carit4-allNoGo                               -0.001540
# face1-encoding                               -0.008100
# face2-recall                                 -0.013559
# face3-distractor                             -0.000242
# face4-encoding-recall                        -0.011962
# face5-encoding-distractor                    -0.006079
# face6-recall-distractor                       0.001658
# VisualMotor                                  -0.003030
# carit_FC                                      0.000290
# face_FC                                      -0.017058
# vism_FC                                      -0.001674
# cort_thickness                               -0.009501
# cort_surface                                 -0.001187
# subcortex                                     0.006893
# Total_Brain_Volume                            0.007776
# Resting_State_FC_75PC                        -0.037966
# All-Modality_con+FC(set1)                     0.005979
# Task_con(set2)                                0.002526
# Non-Task(set3)                               -0.012480
# Task_FC(set4)                                -0.017689
# Task_con+FC(set5)                             0.003085
# All-modality_con(set6)                        0.005498
# All-modality_FC(set7)                        -0.009898
# FC_rest_task(set8)                           -0.038089
#
#                            C_3_2_age_gap_cor+cog-pred  \
# carit1-allNoGo-allGo                         0.002415
# carit3-allGo                                 0.001541
# carit4-allNoGo                              -0.001540
# face1-encoding                              -0.008100
# face2-recall                                -0.013559
# face3-distractor                            -0.000242
# face4-encoding-recall                       -0.011962
# face5-encoding-distractor                   -0.006079
# face6-recall-distractor                      0.001658
# VisualMotor                                 -0.003030
# carit_FC                                     0.000290
# face_FC                                     -0.017058
# vism_FC                                     -0.001674
# cort_thickness                              -0.009501
# cort_surface                                -0.001187
# subcortex                                    0.006893
# Total_Brain_Volume                           0.007776
# Resting_State_FC_75PC                       -0.037966
# All-Modality_con+FC(set1)                    0.005979
# Task_con(set2)                               0.002526
# Non-Task(set3)                              -0.012480
# Task_FC(set4)                               -0.017689
# Task_con+FC(set5)                            0.003085
# All-modality_con(set6)                       0.005498
# All-modality_FC(set7)                       -0.009898
# FC_rest_task(set8)                          -0.038089
#
#                            C_3_2_age-orig+cog-pred_(age_pred)  \
# carit1-allNoGo-allGo                                 0.000696
# carit3-allGo                                         0.004985
# carit4-allNoGo                                       0.008397
# face1-encoding                                       0.011474
# face2-recall                                         0.010137
# face3-distractor                                     0.011543
# face4-encoding-recall                                0.011359
# face5-encoding-distractor                            0.005704
# face6-recall-distractor                              0.006197
# VisualMotor                                         -0.002831
# carit_FC                                             0.001584
# face_FC                                              0.004546
# vism_FC                                              0.009952
# cort_thickness                                       0.005200
# cort_surface                                         0.002958
# subcortex                                           -0.000695
# Total_Brain_Volume                                  -0.001353
# Resting_State_FC_75PC                               -0.006313
# All-Modality_con+FC(set1)                           -0.016495
# Task_con(set2)                                      -0.006875
# Non-Task(set3)                                      -0.003666
# Task_FC(set4)                                        0.003124
# Task_con+FC(set5)                                   -0.014016
# All-modality_con(set6)                              -0.016415
# All-modality_FC(set7)                               -0.006261
# FC_rest_task(set8)                                  -0.004987
#
#                            C_3_2_age-orig+cog-pred_(age_gap)  \
# carit1-allNoGo-allGo                                0.024900
# carit3-allGo                                        0.070320
# carit4-allNoGo                                      0.037631
# face1-encoding                                      0.118718
# face2-recall                                        0.121798
# face3-distractor                                    0.103654
# face4-encoding-recall                               0.047439
# face5-encoding-distractor                           0.158747
# face6-recall-distractor                             0.165347
# VisualMotor                                         0.122309
# carit_FC                                            0.107773
# face_FC                                             0.120125
# vism_FC                                             0.113997
# cort_thickness                                      0.244390
# cort_surface                                        0.078736
# subcortex                                           0.221724
# Total_Brain_Volume                                  0.231958
# Resting_State_FC_75PC                               0.119863
# All-Modality_con+FC(set1)                           0.259028
# Task_con(set2)                                      0.235748
# Non-Task(set3)                                      0.256441
# Task_FC(set4)                                       0.187232
# Task_con+FC(set5)                                   0.236493
# All-modality_con(set6)                              0.258438
# All-modality_FC(set7)                               0.259506
# FC_rest_task(set8)                                  0.190800
#
#                            C_3_2_age-orig+cog-pred_(age_pred_cor)  \
# carit1-allNoGo-allGo                                     0.000322
# carit3-allGo                                             0.003939
# carit4-allNoGo                                           0.008600
# face1-encoding                                           0.010338
# face2-recall                                             0.008810
# face3-distractor                                         0.011419
# face4-encoding-recall                                    0.010773
# face5-encoding-distractor                                0.003372
# face6-recall-distractor                                  0.005800
# VisualMotor                                             -0.004819
# carit_FC                                                 0.001485
# face_FC                                                  0.004537
# vism_FC                                                  0.006912
# cort_thickness                                           0.005086
# cort_surface                                             0.001850
# subcortex                                               -0.000857
# Total_Brain_Volume                                      -0.001541
# Resting_State_FC_75PC                                   -0.007414
# All-Modality_con+FC(set1)                               -0.016786
# Task_con(set2)                                          -0.007353
# Non-Task(set3)                                          -0.003904
# Task_FC(set4)                                            0.002546
# Task_con+FC(set5)                                       -0.014580
# All-modality_con(set6)                                  -0.016683
# All-modality_FC(set7)                                   -0.006647
# FC_rest_task(set8)                                      -0.006099
#
#                            C_3_2_age-orig+cog-pred_(age_gap_cor)  \
# carit1-allNoGo-allGo                                    0.080931
# carit3-allGo                                            0.157999
# carit4-allNoGo                                          0.105185
# face1-encoding                                          0.224745
# face2-recall                                            0.237401
# face3-distractor                                        0.227173
# face4-encoding-recall                                   0.148354
# face5-encoding-distractor                               0.264827
# face6-recall-distractor                                 0.262535
# VisualMotor                                             0.222277
# carit_FC                                                0.259592
# face_FC                                                 0.283905
# vism_FC                                                 0.266702
# cort_thickness                                          0.312446
# cort_surface                                            0.160781
# subcortex                                               0.275779
# Total_Brain_Volume                                      0.296419
# Resting_State_FC_75PC                                   0.280913
# All-Modality_con+FC(set1)                               0.300828
# Task_con(set2)                                          0.288888
# Non-Task(set3)                                          0.308842
# Task_FC(set4)                                           0.299909
# Task_con+FC(set5)                                       0.292541
# All-modality_con(set6)                                  0.300077
# All-modality_FC(set7)                                   0.312282
# FC_rest_task(set8)                                      0.300255
#
#                            C_3_age_pred+age+cog-pred  \
# carit1-allNoGo-allGo                        0.026817
# carit3-allGo                                0.077263
# carit4-allNoGo                              0.043149
# face1-encoding                              0.117832
# face2-recall                                0.128315
# face3-distractor                            0.113170
# face4-encoding-recall                       0.054655
# face5-encoding-distractor                   0.165858
# face6-recall-distractor                     0.159486
# VisualMotor                                 0.123009
# carit_FC                                    0.167094
# face_FC                                     0.202849
# vism_FC                                     0.156746
# cort_thickness                              0.250092
# cort_surface                                0.088920
# subcortex                                   0.215969
# Total_Brain_Volume                          0.221618
# Resting_State_FC_75PC                       0.212107
# All-Modality_con+FC(set1)                   0.288086
# Task_con(set2)                              0.235847
# Non-Task(set3)                              0.283840
# Task_FC(set4)                               0.224527
# Task_con+FC(set5)                           0.253769
# All-modality_con(set6)                      0.287917
# All-modality_FC(set7)                       0.291964
# FC_rest_task(set8)                          0.251508
#
#                            C_3_age_gap+age+cog-pred  \
# carit1-allNoGo-allGo                       0.002613
# carit3-allGo                               0.011928
# carit4-allNoGo                             0.013914
# face1-encoding                             0.010588
# face2-recall                               0.016654
# face3-distractor                           0.021059
# face4-encoding-recall                      0.018575
# face5-encoding-distractor                  0.012815
# face6-recall-distractor                    0.000336
# VisualMotor                               -0.002130
# carit_FC                                   0.060905
# face_FC                                    0.087269
# vism_FC                                    0.052702
# cort_thickness                             0.010902
# cort_surface                               0.013142
# subcortex                                 -0.006451
# Total_Brain_Volume                        -0.011692
# Resting_State_FC_75PC                      0.085931
# All-Modality_con+FC(set1)                  0.012563
# Task_con(set2)                            -0.006776
# Non-Task(set3)                             0.023733
# Task_FC(set4)                              0.040418
# Task_con+FC(set5)                          0.003260
# All-modality_con(set6)                     0.013063
# All-modality_FC(set7)                      0.026197
# FC_rest_task(set8)                         0.055722
#
#                            C_3_age_pred_cor+age+cog-pred  \
# carit1-allNoGo-allGo                            0.027191
# carit3-allGo                                    0.078309
# carit4-allNoGo                                  0.042945
# face1-encoding                                  0.118968
# face2-recall                                    0.129643
# face3-distractor                                0.113294
# face4-encoding-recall                           0.055240
# face5-encoding-distractor                       0.168190
# face6-recall-distractor                         0.159884
# VisualMotor                                     0.124997
# carit_FC                                        0.167193
# face_FC                                         0.202858
# vism_FC                                         0.159787
# cort_thickness                                  0.250206
# cort_surface                                    0.090029
# subcortex                                       0.216131
# Total_Brain_Volume                              0.221806
# Resting_State_FC_75PC                           0.213208
# All-Modality_con+FC(set1)                       0.288376
# Task_con(set2)                                  0.236325
# Non-Task(set3)                                  0.284078
# Task_FC(set4)                                   0.225105
# Task_con+FC(set5)                               0.254333
# All-modality_con(set6)                          0.288184
# All-modality_FC(set7)                           0.292351
# FC_rest_task(set8)                              0.252621
#
#                            C_3_age_gap_cor+age+cog-pred
# carit1-allNoGo-allGo                          -0.053419
# carit3-allGo                                  -0.075751
# carit4-allNoGo                                -0.053640
# face1-encoding                                -0.095439
# face2-recall                                  -0.098949
# face3-distractor                              -0.102460
# face4-encoding-recall                         -0.082340
# face5-encoding-distractor                     -0.093264
# face6-recall-distractor                       -0.096852
# VisualMotor                                   -0.102098
# carit_FC                                      -0.090914
# face_FC                                       -0.076510
# vism_FC                                       -0.100004
# cort_thickness                                -0.057155
# cort_surface                                  -0.068903
# subcortex                                     -0.060506
# Total_Brain_Volume                            -0.076154
# Resting_State_FC_75PC                         -0.075119
# All-Modality_con+FC(set1)                     -0.029238
# Task_con(set2)                                -0.059916
# Non-Task(set3)                                -0.028668
# Task_FC(set4)                                 -0.072259
# Task_con+FC(set5)                             -0.052788
# All-modality_con(set6)                        -0.028576
# All-modality_FC(set7)                         -0.026579
# FC_rest_task(set8)                            -0.053733
#
# [26 rows x 59 columns]

# %%
#save extra tables

#save table with r2 only (not uniq or common part of r2)
pd.concat([df_r2_one, df_r2_two, df_r2_three], axis=1).to_csv(path+'r2_ages_cog_fluid_age2.csv')

df_corR_one.to_csv(path+'correlation_r_agepreds_cog_fluid_age2.csv')

df_corPval_one.to_csv(path+'correlation_pval_agepreds_cog_fluid_age2.csv')
